# %%
from ML_models import *

# %%
a=2
b=3

# %%
c=[a,b]

# %%
c
# Out:
# [2, 3]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,10))
sns.barplot(y=[1,3],x=["a","b"])
plt.yticks(np.arange(0, 3, 0.15))
plt.show()

# %%
plt.figure(figsize=(20,10))
y=[1,3]
sns.barplot(y=[1,3],x=["a","b"])
plt.yticks(np.arange(min(y), max(y)+1, 0.1))
plt.show()
